# %%
"""
Cálculo Numérico — Séries Numéricas
=========================================
Implemente métodos numéricos para Sequências e Séries Numéricas em Python.

Temas para aplicar as funções, implemente todos os métodos dentro de cada tema:
  1. Sequências
  2. Séries Numéricas
  3. Série telescópica, série geométrica e série harmônica
  4. Série de potências e expansão em séries 
"""
